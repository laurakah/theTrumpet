# %%
import pandas as pd
import numpy as np

from collections import Counter
import codecs
import nltk
#nltk.download('averaged_perceptron_tagger')

import matplotlib.pyplot as plt

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

english_stopwords = set(stopwords.words('english'))

with codecs.open("trump_press_conf.txt", "r", "utf-8-sig") as text_file:
    pc = text_file.read()
    
with codecs.open("trump_interview.txt", "r", "utf-8-sig") as text_file:
    i = text_file.read()
    
r = pc + i

tokenizer = RegexpTokenizer(r'\w+')
_tokens = tokenizer.tokenize(r)
tokens = [t for t in _tokens if t.lower() not in english_stopwords]

# %%
len(r)
# Out:
# 9765973

# %%
density_text = r[:9765973]

tokenizer = RegexpTokenizer(r'\w+')
_density_tokens = tokenizer.tokenize(density_text)
density_tokens = [t for t in _density_tokens if t.lower() not in english_stopwords]

# %%
st = len(set(density_tokens))
lt = len(density_tokens)
y = [st*100/lt]
print(y)

fig = plt.figure()
ax = fig.add_subplot(111)
N = 1
ind = np.arange(N)
width = 0.7
rect = ax.bar(ind, y, width, color="black")
ax.set_xlim(-width,len(ind)+width)
ax.set_ylim(0,100)
ax.set_ylabel("Score")
ax.set_title("Lexical Diversity")
xTickMarks = ["Lexical Diversity Meter"]
ax.set_xticks(ind+width)
xtickNames = ax.set_xticklabels(xTickMarks)
plt.setp(xtickNames, rotation=45, fontsize=10)
ax.legend( (rect[0], ("") ))
plt.show()
# Out:
# [2.5210713336253927]

# %%
st = len(set(tokens))
lt = len(tokens)
y = [st*100/lt]
print(y)

fig = plt.figure()
ax = fig.add_subplot(111)
N = 1
ind = np.arange(N)
width = 0.7
rect = ax.bar(ind, y, width, color="black")
ax.set_xlim(-width,len(ind)+width)
ax.set_ylim(0,100)
ax.set_ylabel("Score")
ax.set_title("Lexical Diversity")
xTickMarks = ["Lexical Diversity Meter"]
ax.set_xticks(ind+width)
xtickNames = ax.set_xticklabels(xTickMarks)
plt.setp(xtickNames, rotation=45, fontsize=10)
ax.legend( (rect[0], ("") ))
plt.show()
# Out:
# [2.5210713336253927]

# %%
tagged = nltk.pos_tag(tokens)
counts = Counter(tag for word,tag in tagged)
keys = counts.keys()
y_pos = np.arange(len(keys))
p = [counts[k] for k in keys]
error = np.random.rand(len(keys))

# %%
plt.figure(figsize=(20, 12))

y_pos = np.arange(len(keys))

plt.barh(y_pos, p, align='center', alpha=0.5)
plt.yticks(y_pos, keys)

plt.show()

# %%
dist = nltk.FreqDist(tokens)
dist.plot(20, cumulative=False);

# %%
text = nltk.Text(_tokens)
print("\n".join(text.collocation_list(num=20)))
# Out:
# United States
# New York
# little bit
# North Korea
# long time
# Hillary Clinton
# years ago
# Middle East
# Saudi Arabia
# Prime Minister
# health care
# White House
# real estate
# President Obama
# Supreme Court
# New Hampshire
# Donald Trump
# number one
# fake news
# South Korea

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# /home/luci/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_custom_kernels.py:36: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_custom_kernels.cu' mode='r' encoding='utf8'>
#   SRC = (PWD / "_custom_kernels.cu").open("r", encoding="utf8").read()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_custom_kernels.py:39: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_murmur3.cu' mode='r' encoding='utf8'>
#   MMH_SRC = (PWD / "_murmur3.cu").open("r", encoding="utf8").read()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
locations = []
organizations = []
persons = []
dates = []
times = []
percents = []
facilities = []
gpes = []
ordinals = []
cardinals = []
norps = []
moneys = []
laws = []
products = []
quantities = []

# %%
nlp.max_length = 19000000

# %%
splitted_text = r.split(" ")

# %%
len(r)/20
# Out:
# 488298.65

# %%
len(splitted_text)/20
# Out:
# 90791.4

# %%
part1, part2, part3, part4, part5, part6, part7, part8, part9, part10, part11, part12, part13, part14, part15, part16, part17, part18, part19, part20 = [splitted_text[i:i + 90792] for i in range(0, len(splitted_text), 90792)]

# %%
len(part6)
# Out:
# 90792

# %%
part1 = " ".join(part1)

# %%
part2 = " ".join(part2)

# %%
part3 = " ".join(part3)

# %%
part4 = " ".join(part4)

# %%
part5 = " ".join(part5)

# %%
part6 = " ".join(part6)

# %%
part7 = " ".join(part7)
part8 = " ".join(part8)
part9 = " ".join(part9)
part10 = " ".join(part10)

part11 = " ".join(part11)
part12 = " ".join(part12)
part13 = " ".join(part13)
part14 = " ".join(part14)
part15 = " ".join(part15)
part16 = " ".join(part16)
part17 = " ".join(part17)
part18 = " ".join(part18)
part19 = " ".join(part19)
part20 = " ".join(part20)

# %%
#chunks = [(X.text, X.label_) for X in nlp(r).ents]
chunk1 = [(X.text, X.label_) for X in nlp(part1).ents]

# %%
chunk2 = [(X.text, X.label_) for X in nlp(part2).ents]

# %%
chunk3 = [(X.text, X.label_) for X in nlp(part3).ents]

# %%
chunk4 = [(X.text, X.label_) for X in nlp(part4).ents]

# %%
chunk5 = [(X.text, X.label_) for X in nlp(part5).ents]

# %%
chunk6 = [(X.text, X.label_) for X in nlp(part6).ents]

# %%
chunk7 = [(X.text, X.label_) for X in nlp(part7).ents]

# %%
chunk8 = [(X.text, X.label_) for X in nlp(part8).ents]

# %%
chunk9 = [(X.text, X.label_) for X in nlp(part9).ents]

# %%
chunk10 = [(X.text, X.label_) for X in nlp(part10).ents]

# %%
chunk11 = [(X.text, X.label_) for X in nlp(part11).ents]

# %%
chunk12 = [(X.text, X.label_) for X in nlp(part12).ents]

# %%
chunk13 = [(X.text, X.label_) for X in nlp(part13).ents]

# %%
chunk14 = [(X.text, X.label_) for X in nlp(part14).ents]

# %%
chunk15 = [(X.text, X.label_) for X in nlp(part15).ents]

# %%
chunk16 = [(X.text, X.label_) for X in nlp(part16).ents]

# %%
chunk17 = [(X.text, X.label_) for X in nlp(part17).ents]

# %%
chunk18 = [(X.text, X.label_) for X in nlp(part18).ents]

# %%
chunk19 = [(X.text, X.label_) for X in nlp(part19).ents]

# %%
chunk20 = [(X.text, X.label_) for X in nlp(part20).ents]

# %%
list_of_chunks = [chunk1, chunk2, chunk3, chunk4, chunk5, chunk6, chunk7, chunk8, chunk9, chunk10, chunk11, chunk12, chunk13, chunk14, chunk15, chunk16, chunk17, chunk18, chunk19, chunk20]

for chunks in list_of_chunks:
    for chunk in chunks:
        if chunk[1] == "PERSON": 
            persons.append(chunk[0])
        if chunk[1] == "LOC": 
            locations.append(chunk[0])
        if chunk[1] == "ORG": 
            organizations.append(chunk[0])
        if chunk[1] == "DATE": 
            dates.append(chunk[0])
        if chunk[1] == "TIME": 
            times.append(chunk[0])
        if chunk[1] == "PERCENT": 
            percents.append(chunk[0])
        if chunk[1] == "FAC": 
            facilities.append(chunk[0])
        if chunk[1] == "GPE": 
            gpes.append(chunk[0])
        if chunk[1] == "MONEY":
            moneys.append(chunk[0])
        if chunk[1] == "LAW":
            laws.append(chunk[0])
        if chunk[1] == "CARDINAL":
            cardinals.append(chunk[0])
        if chunk[1] == "NORP":
            norps.append(chunk[0])
        if chunk[1] == "ORDINAL":
            ordinals.append(chunk[0])
        if chunk[1] == "PRODUCT":
            products.append(chunk[0])
        if chunk[1] == "QUANTITY":
            quantities.append(chunk[0])

# %%
import collections
import operator

def count_words(value_list):
    values = {}
    for word in value_list:
        if word not in values.keys():
            values[word] = 1
        else:
            values[word] += 1
    values_sorted = collections.OrderedDict(sorted(values.items(), key=operator.itemgetter(1), reverse=True))
    return values_sorted

# %%
person_counts = count_words(persons)
location_counts = count_words(locations)
organization_counts = count_words(organizations)
facility_counts = count_words(facilities)
gpe_counts = count_words(gpes)
norp_counts = count_words(norps)

# %%
gpe_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ede5d466266f> in <module>
# ----> 1 gpe_counts
#
# NameError: name 'gpe_counts' is not defined

# %%
#displacy.render(nlp(str(r)), jupyter=True, style='ent')

# %%
#displacy.render(nlp(str(r)), style='dep', jupyter = True, options = {'distance': 120})

# %%
plt.figure(figsize=(20, 12))

y_pos = np.arange(len(person_counts.keys()))

plt.barh(y_pos, person_counts.values(), align='center', alpha=0.5)
plt.yticks(y_pos, person_counts.keys())

plt.show()

# %%
from pymarkovchain import MarkovChain
mc = MarkovChain()
for i in range(1,30):
    mc.generateDatabase(r)
    g = mc.generateString()
    print(g)
# Out:
# /home/luci/anaconda3/lib/python3.7/site-packages/pymarkovchain/MarkovChain.py:54: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn('Database file corrupt or not found, using empty database')
# WARNING:root:Database file corrupt or not found, using empty database
# He folded on the other 15,000
# Every time we spoke to the issue at hand
# You have to start pushing them very nicely and it's a faux story
# They take something that the World Trade Center attack but I wanted during the campaign, except way at the forefront
# They're gonna raise the debt ceiling and he'll be a point
# He would kill terrorists
# You know, all these different emotions are things that were very bad --I hope you're not fake and I want local education
# The wall is being beaten up now saying, gee, whiz -- you know, in all of the United States
# I'm getting now the guy's having a good thing, not a threat to us, we do indeed have a lot of things are happening
# I thought very well, right
# They changed the title
# We'll be meeting with a number of soldiers we spent $1
# I can tell you
# Now we have with our military; they want more nuclear weapons
# But you know -- well, I think deals are wonderful things about us, we have, our soldiers, our soldiers, our military, Jeanine
# I’ll tell you
# Jim Brown, who's ---- the stupid deals anymore
# You would thought what happened
# He has been very, very hard to make anything anymore
# And in this country
# Ok, you ready
# No, we're looking at it
# And I think we would've wasted a lot bigger canvas to play it a home run with somebody that I'll be doing something very, very sad story, about two minutes, they agree with me, that I think so
# But certainly, they're not -- you saw the Border Patrols invited me
# I agree with me
# The fact that other people in the background watching somebody else spent $48 million
# Recently somebody said there is no tax
# I make it
# But if those two

# %%
import textstat
# Out:
# /home/luci/anaconda3/lib/python3.7/site-packages/textstat/textstat.py:20: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/lib/python3.7/site-packages/textstat/easy_words.txt'>
#   pkg_resources.resource_stream('textstat', 'easy_words.txt')
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
textstat.flesch_reading_ease(r)
# Out:
# 81.22

# %%
textstat.smog_index(r)
# Out:
# 8.9

# %%
textstat.flesch_kincaid_grade(r)
# Out:
# 5.8

# %%
textstat.coleman_liau_index(r)
# Out:
# 6.61

# %%
textstat.automated_readability_index(r)
# Out:
# 7.1

# %%
textstat.dale_chall_readability_score(r)
# Out:
# 0.87

# %%
textstat.difficult_words(r)
# Out:
# 11652

# %%
textstat.linsear_write_formula(r)
# Out:
# 5.777777777777778

# %%
textstat.gunning_fog(r)
# Out:
# 6.28

# %%
textstat.text_standard(r)
# Out:
# '5th and 6th grade'

# %%
textstat.syllable_count(r, lang='en_US')
# Out:
# 2366482

# %%
sentiment_string = r[:10000000]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
analyser.polarity_scores(sentiment_string)
# Out:
# {'neg': 0.067, 'neu': 0.771, 'pos': 0.162, 'compound': 1.0}

# %%
from pattern.en import parse, Sentence
from pattern.en import modality

# %%
def fact(string):
    sent = parse(string, lemmata=False)
    sent = Sentence(sent)
    return modality(sent)

# %%
fact(sentiment_string)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-cf88f8814408> in <module>
# ----> 1 fact(sentiment_string)
#
# <ipython-input-6-fc54fef2fe76> in fact(string)
#       1 def fact(string):
# ----> 2     sent = parse(string, lemmata=False)
#       3     sent = Sentence(sent)
#       4     return modality(sent)
#
# ~/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/en/__init__.py in parse(s, *args, **kwargs)
#     167     """ Returns a tagged Unicode string.
#     168     """
# --> 169     return parser.parse(s, *args, **kwargs)
#     170
#     171
#
# ~/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/__init__.py in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#    1170             # Tagger (required by chunker, labeler & lemmatizer).
#    1171             if tags or chunks or relations or lemmata:
# -> 1172                 s[i] = self.find_tags(s[i], **kwargs)
#    1173             else:
#    1174                 s[i] = [[w] for w in s[i]]
#
# ~/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/en/__init__.py in find_tags(self, tokens, **kwargs)
#     112         if kwargs.get("tagset") == UNIVERSAL:
#     113             kwargs.setdefault("map", lambda token, tag: penntreebank2universal(token, tag))
# --> 114         return _Parser.find_tags(self, tokens, **kwargs)
#     115
#     116
#
# ~/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/__init__.py in find_tags(self, tokens, **kwargs)
#    1118                    language = kwargs.get("language", self.language),
#    1119                     default = kwargs.get("default", self.default),
# -> 1120                         map = kwargs.get("map", None))
#    1121
#    1122     def find_chunks(self, tokens, **kwargs):
#
# ~/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/__init__.py in find_tags(tokens, lexicon, model, morphology, context, entities, default, language, map, **kwargs)
#    1538     # Tag named entities.
#    1539     if entities is not None:
# -> 1540         tagged = entities.apply(tagged)
#    1541     # Map tags with a custom function.
#    1542     if map is not None:
#
# ~/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/__init__.py in apply(self, tokens)
#     972             if RE_ENTITY1.match(w) \
#     973             or RE_ENTITY2.match(w) \
# --> 974             or RE_ENTITY3.match(w):
#     975                 tokens[i][1] = self.tag
#     976             if w in self:
#
# KeyboardInterrupt:

# %%
from pattern.en import sentiment
# Out:
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-en.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-fr.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-de.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-es.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-nl.txt'>
#   w = (w.strip() for w in w.read().split(","))

# %%
sentiment(sentiment_string)
# Out:
# (0.15748481061850417, 0.5386109525073163)

# %%
from pattern.en import modality
# Out:
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-en.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-fr.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-de.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-es.txt'>
#   w = (w.strip() for w in w.read().split(","))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/__init__.py:284: ResourceWarning: unclosed file <_io.BufferedReader name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/vector/stopwords-nl.txt'>
#   w = (w.strip() for w in w.read().split(","))

# %%
modality(sentiment_string)
# Out:
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/__init__.py:625: DeprecationWarning: generator '_read' raised StopIteration
#   dict.update(self, (x.split(" ")[:2] for x in _read(self._path) if len(x.split(" ")) > 1))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/__init__.py:625: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/en/en-lexicon.txt' mode='r' encoding='utf-8'>
#   dict.update(self, (x.split(" ")[:2] for x in _read(self._path) if len(x.split(" ")) > 1))
# /home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/__init__.py:959: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/luci/anaconda3/envs/twitter/lib/python3.6/site-packages/pattern/text/en/en-entities.txt' mode='r' encoding='utf-8'>
#   for x in _read(self.path):
# 0.4055269930565023

# %%
from pattern.en import mood

# %%
moods = []

# %%
for sentence in r.split("."):
    moods.append(mood(sentence))

# %%
mood_ser = pd.Series(moods)

# %%
mood_ser.value_counts(normalize=True)
# Out:
# indicative     0.782755
# conditional    0.128697
# imperative     0.083170
# subjunctive    0.005378
# dtype: float64

# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.generate()
# Out:
# Using TensorFlow backend.
# /home/luci/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /home/luci/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py:5851: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/luci/.keras/keras.json' mode='r' encoding='UTF-8'>
#   _config = json.load(open(_config_path))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/luci/anaconda3/lib/python3.7/site-packages/keras/engine/training_utils.py:811: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(loss, collections.Mapping):
# The Gun Roasts Adding a Window in the Studios Internet Camera with as a full free thing that she was too sleeping and then have a stream

# %%
texts = r.split(".")

# %%
textgen.train_on_texts(texts, num_epochs=2,  gen_epochs=2)
textgen.generate()
# Out:
# Training on 9,765,974 character sequences.
# /home/luci/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/2
# 76296/76296 [==============================] - 12634s 166ms/step - loss: 1.2464
# Epoch 2/2
# 76296/76296 [==============================] - 12673s 166ms/step - loss: 1.1731
# ####################
# Temperature: 0.2
# ####################
#  I think it's a great guy
#
#  I think they don't want to do a lot of people that are going to be a great person
#
#  I think the people are going to be a great thing
#
# ####################
# Temperature: 0.5
# ####################
#  I don't think that, they were the best general is they are four it down and the best and the situation -- as far as four years ago with the UK
#
#  You know, it was a discussion
#
#  I think you have to do that
#
# ####################
# Temperature: 1.0
# ####################
#  Madur, you look at all the hearroging guy is right
#
#  So they'll come back
#
# We do get out to take a look
#
#  I think it's a hard year of a lot of personally one of the worst things we can get out of the politicians and the fun that are a great -- and they can get him very, very simple
