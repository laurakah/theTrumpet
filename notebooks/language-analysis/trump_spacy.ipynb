# %%
import pandas as pd
import numpy as np

from collections import Counter
import codecs
import nltk
#nltk.download('averaged_perceptron_tagger')

import matplotlib.pyplot as plt

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

english_stopwords = set(stopwords.words('english'))

with codecs.open("trump_long.txt", "r", "utf-8-sig") as text_file:
    r = text_file.read()
    tokenizer = RegexpTokenizer(r'\w+')
    _tokens = tokenizer.tokenize(r)
    tokens = [t for t in _tokens if t.lower() not in english_stopwords]

# %%
st = len(set(tokens))
lt = len(tokens)
y = [st*100/lt]
print(y)

fig = plt.figure()
ax = fig.add_subplot(111)
N = 1
ind = np.arange(N)
width = 0.7
rect = ax.bar(ind, y, width, color="black")
ax.set_xlim(-width,len(ind)+width)
ax.set_ylim(0,100)
ax.set_ylabel("Score")
ax.set_title("Lexical Diversity")
xTickMarks = ["Lexical Diversity Meter"]
ax.set_xticks(ind+width)
xtickNames = ax.set_xticklabels(xTickMarks)
plt.setp(xtickNames, rotation=45, fontsize=10)
ax.legend( (rect[0], ("") ))
plt.show()
# Out:
# [1.7251447141261298]

# %%
tagged = nltk.pos_tag(tokens)
counts = Counter(tag for word,tag in tagged)
keys = counts.keys()
y_pos = np.arange(len(keys))
p = [counts[k] for k in keys]
error = np.random.rand(len(keys))

# %%
plt.figure(figsize=(20, 12))

y_pos = np.arange(len(keys))

plt.barh(y_pos, p, align='center', alpha=0.5)
plt.yticks(y_pos, keys)

plt.show()

# %%
dist = nltk.FreqDist(tokens)
dist.plot(20, cumulative=False);

# %%
text = nltk.Text(_tokens)
print("\n".join(text.collocation_list(num=20)))
# Out:
# United States
# North Korea
# long time
# little bit
# White House
# Prime Minister
# New York
# tax cuts
# law enforcement
# God bless
# Supreme Court
# fake news
# years ago
# Middle East
# health care
# great job
# South Korea
# many years
# European Union
# President Obama

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# /home/luci/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_custom_kernels.py:36: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_custom_kernels.cu' mode='r' encoding='utf8'>
#   SRC = (PWD / "_custom_kernels.cu").open("r", encoding="utf8").read()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_custom_kernels.py:39: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/luci/anaconda3/lib/python3.7/site-packages/thinc/neural/_murmur3.cu' mode='r' encoding='utf8'>
#   MMH_SRC = (PWD / "_murmur3.cu").open("r", encoding="utf8").read()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
locations = []
organizations = []
persons = []
dates = []
times = []
percents = []
facilities = []
gpes = []
ordinals = []
cardinals = []
norps = []
moneys = []
laws = []
products = []
quantities = []

# %%
nlp.max_length = 19000000

# %%
splitted_text = r.split(" ")

# %%
len(r)/20
# Out:
# 934171.3

# %%
len(splitted_text)/20
# Out:
# 168616.15

# %%
part1, part2, part3, part4, part5, part6, part7, part8, part9, part10, part11, part12, part13, part14, part15, part16, part17, part18, part19, part20 = [splitted_text[i:i + 168617] for i in range(0, len(splitted_text), 168617)]

# %%
len(part6)
# Out:
# 168617

# %%
part1 = " ".join(part1)

# %%
part2 = " ".join(part2)

# %%
part3 = " ".join(part3)

# %%
part4 = " ".join(part4)

# %%
part5 = " ".join(part5)

# %%
part6 = " ".join(part6)

# %%
part7 = " ".join(part7)
part8 = " ".join(part8)
part9 = " ".join(part9)
part10 = " ".join(part10)

part11 = " ".join(part11)
part12 = " ".join(part12)
part13 = " ".join(part13)
part14 = " ".join(part14)
part15 = " ".join(part15)
part16 = " ".join(part16)
part17 = " ".join(part17)
part18 = " ".join(part18)
part19 = " ".join(part19)
part20 = " ".join(part20)

# %%
#chunks = [(X.text, X.label_) for X in nlp(r).ents]
chunk1 = [(X.text, X.label_) for X in nlp(part1).ents]

# %%
chunk2 = [(X.text, X.label_) for X in nlp(part2).ents]

# %%
chunk3 = [(X.text, X.label_) for X in nlp(part3).ents]

# %%
chunk4 = [(X.text, X.label_) for X in nlp(part4).ents]

# %%
chunk5 = [(X.text, X.label_) for X in nlp(part5).ents]

# %%
chunk6 = [(X.text, X.label_) for X in nlp(part6).ents]

# %%
chunk7 = [(X.text, X.label_) for X in nlp(part7).ents]

# %%
chunk8 = [(X.text, X.label_) for X in nlp(part8).ents]

# %%
chunk9 = [(X.text, X.label_) for X in nlp(part9).ents]

# %%
chunk10 = [(X.text, X.label_) for X in nlp(part10).ents]

# %%
chunk11 = [(X.text, X.label_) for X in nlp(part11).ents]

# %%
chunk12 = [(X.text, X.label_) for X in nlp(part12).ents]

# %%
chunk13 = [(X.text, X.label_) for X in nlp(part13).ents]

# %%
chunk14 = [(X.text, X.label_) for X in nlp(part14).ents]

# %%
chunk15 = [(X.text, X.label_) for X in nlp(part15).ents]

# %%
chunk16 = [(X.text, X.label_) for X in nlp(part16).ents]

# %%
chunk17 = [(X.text, X.label_) for X in nlp(part17).ents]

# %%
chunk18 = [(X.text, X.label_) for X in nlp(part18).ents]

# %%
chunk19 = [(X.text, X.label_) for X in nlp(part19).ents]

# %%
chunk20 = [(X.text, X.label_) for X in nlp(part20).ents]

# %%
list_of_chunks = [chunk1, chunk2, chunk3, chunk4, chunk5, chunk6, chunk7, chunk8, chunk9, chunk10, chunk11, chunk12, chunk13, chunk14, chunk15, chunk16, chunk17, chunk18, chunk19, chunk20]

for chunks in list_of_chunks:
    for chunk in chunks:
        if chunk[1] == "PERSON": 
            persons.append(chunk[0])
        if chunk[1] == "LOC": 
            locations.append(chunk[0])
        if chunk[1] == "ORG": 
            organizations.append(chunk[0])
        if chunk[1] == "DATE": 
            dates.append(chunk[0])
        if chunk[1] == "TIME": 
            times.append(chunk[0])
        if chunk[1] == "PERCENT": 
            percents.append(chunk[0])
        if chunk[1] == "FAC": 
            facilities.append(chunk[0])
        if chunk[1] == "GPE": 
            gpes.append(chunk[0])
        if chunk[1] == "MONEY":
            moneys.append(chunk[0])
        if chunk[1] == "LAW":
            laws.append(chunk[0])
        if chunk[1] == "CARDINAL":
            cardinals.append(chunk[0])
        if chunk[1] == "NORP":
            norps.append(chunk[0])
        if chunk[1] == "ORDINAL":
            ordinals.append(chunk[0])
        if chunk[1] == "PRODUCT":
            products.append(chunk[0])
        if chunk[1] == "QUANTITY":
            quantities.append(chunk[0])

# %%
import collections
import operator

def count_words(value_list):
    values = {}
    for word in value_list:
        if word not in values.keys():
            values[word] = 1
        else:
            values[word] += 1
    values_sorted = collections.OrderedDict(sorted(values.items(), key=operator.itemgetter(1), reverse=True))
    return values_sorted

# %%
person_counts = count_words(persons)
location_counts = count_words(locations)
organization_counts = count_words(organizations)
facility_counts = count_words(facilities)
gpe_counts = count_words(gpes)
norp_counts = count_words(norps)

# %%
norp_counts
# Out:
# OrderedDict([('American', 4647),
#              ('Democrats', 2919),
#              ('Americans', 1731),
#              ('Republicans', 1103),
#              ('Democrat', 823),
#              ('Republican', 693),
#              ('African American', 272),
#              ('Hispanic', 229),
#              ('African-American', 202),
#              ('Kurds', 164),
#              ('Jewish', 147),
#              ('Russian', 143),
#              ('ISIS', 142),
#              ('Marines', 111),
#              ('Asian', 106),
#              ('Hispanic American', 94),
#              ('African-Americans', 93),
#              ('Palestinians', 91),
#              ('Sean', 85),
#              ('African Americans', 84),
#              ('Mexican', 82),
#              ('Chinese', 81),
#              ('Russians', 77),
#              ('Iranian', 75),
#              ('Democratic', 74),
#              ('Christian', 71),
#              ('Christians', 70),
#              ('Islamic', 70),
#              ('North Korean', 68),
#              ('French', 64),
#              ('Asian American', 62),
#              ('Hispanics', 61),
#              ('Japanese', 60),
#              ('Muslim', 59),
#              ('European', 56),
#              ('Indian', 54),
#              ('British', 53),
#              ('Polish', 48),
#              ('Irish', 46),
#              ('Ukrainian', 44),
#              ('German', 43),
#              ('Venezuelan', 43),
#              ('Cuban', 40),
#              ('democrats', 38),
#              ('Muslims', 38),
#              ('Hispanic Americans', 37),
#              ('Jews', 36),
#              ('Italian', 36),
#              ('Afghan', 34),
#              ('Greek', 34),
#              ('Nazi', 32),
#              ('Israeli', 31),
#              ('Syrian', 30),
#              ('Israelis', 30),
#              ('Hispanic-American', 29),
#              ('Loyal', 29),
#              ('Marine', 29),
#              ('pro-American', 28),
#              ('Australian', 27),
#              ('Nazis', 24),
#              ('Southern', 24),
#              ('Asians', 24),
#              ('Korean', 24),
#              ('African', 23),
#              ('South Korean', 23),
#              ('Arab', 19),
#              ('Iranians', 18),
#              ('Turkish', 16),
#              ('Asian-American', 16),
#              ('Hispanic-Americans', 15),
#              ('Poles', 15),
#              ('republicans', 14),
#              ('Venezuelans', 14),
#              ('Vietnamese', 14),
#              ('Finnish', 13),
#              ('Canadian', 13),
#              ('Dems', 13),
#              ('Baltic', 13),
#              ('Saudi', 12),
#              ('Asian Americans', 12),
#              ('Pocahontas', 12),
#              ('Shinzo', 12),
#              ('conservatives', 12),
#              ('Palestinian', 12),
#              ('Lebanese', 12),
#              ('democrat', 11),
#              ('Native American', 10),
#              ('Libyan', 10),
#              ('Biden', 10),
#              ('Asian-Americans', 9),
#              ('I.', 8),
#              ('Pakistani', 8),
#              ('Australians', 8),
#              ('Instagram', 8),
#              ('Europeans', 8),
#              ('Texans', 8),
#              ('Koreans', 8),
#              ('Inaudible].I', 7),
#              ('Bidens', 7),
#              ('Cubans', 7),
#              ('anti-Semitic', 7),
#              ('Mexicans', 7),
#              ('Adrian', 7),
#              ('Egyptian', 7),
#              ('Indians', 6),
#              ('Syrians', 6),
#              ('Jordanian', 6),
#              ('Saudis', 6),
#              ('communist', 6),
#              ('republican', 6),
#              ('Made', 6),
#              ('Soviet', 6),
#              ('Redcoats', 5),
#              ('Catholic', 5),
#              ('Elijah', 5),
#              ('All-American', 5),
#              ('Tlaib', 5),
#              ('anti-Jewish', 5),
#              ('the African Americans', 5),
#              ('Puerto Rican', 5),
#              ('Polish-Americans', 5),
#              ('Canadians', 5),
#              ('Iraqi', 5),
#              ('Spanish', 5),
#              ('Kurdish', 4),
#              ('North American', 4),
#              ('Turks', 4),
#              ('Yankee', 4),
#              ('Indian American', 4),
#              ('Indian Americans', 4),
#              ('Native Americans', 4),
#              ('democratic', 4),
#              ('Dutch', 4),
#              ('Norwegians', 4),
#              ('Catch', 4),
#              ('Brazilian', 4),
#              ('Greek Americans', 4),
#              ('Aphrodite', 4),
#              ('Nigerian', 4),
#              ('Congresswoman', 3),
#              ('Latin American', 3),
#              ('English', 3),
#              ('Sebastian', 3),
#              ('Hindus', 3),
#              ('Sikhs', 3),
#              ('Romanian', 3),
#              ('Afghans', 3),
#              ('Tamim', 3),
#              ('--Wait', 3),
#              ('Florence', 3),
#              ('anti-American', 3),
#              ('Socialist', 3),
#              ('ICE', 3),
#              ('all-American', 3),
#              ('Jewish Americans', 3),
#              ('Southeast Asian', 3),
#              ('Washington Democrats', 3),
#              ('Floridians', 3),
#              ('medians', 3),
#              ('Kazakhstani', 3),
#              ('Islamist', 3),
#              ('South Koreans', 3),
#              ('North Koreans', 3),
#              ('neo-Nazis', 3),
#              ('D', 2),
#              ('Panhandle', 2),
#              ('--Well', 2),
#              ('flavors?So', 2),
#              ('Conservatives', 2),
#              ('vanquish', 2),
#              ('Liberal Democrat', 2),
#              ('Ukrainians', 2),
#              ('Italians', 2),
#              ('Buddhists', 2),
#              ('going?Thank', 2),
#              ('AMVETS', 2),
#              ('communists', 2),
#              ('Africans', 2),
#              ('Sikorsky', 2),
#              ('Sherman', 2),
#              ('--Sure', 2),
#              ('un-American', 2),
#              ('american', 2),
#              ('Polish-American', 2),
#              ('Angry Democrats', 2),
#              ('Trish', 2),
#              ('Evans', 2),
#              ('Minnesotans', 2),
#              ('Trevor', 2),
#              ('Irish Americans', 2),
#              ('Steny', 2),
#              ('Irish American', 2),
#              ('Catholics', 2),
#              ('Shia', 2),
#              ('American Marines', 2),
#              ('Saudi Arabian', 2),
#              ('Laughter]I', 2),
#              ('Middle Eastern', 2),
#              ('Applause]Hispanic Americans', 2),
#              ('the Native Americans', 2),
#              ('stellar', 2),
#              ('Lennox', 2),
#              ('Curtis', 2),
#              ('Moonbeam', 2),
#              ('New American', 2),
#              ('Norwegian', 2),
#              ('Strange', 2),
#              ('Judeo-Christian', 2),
#              ('Nazism', 2),
#              ('Applause]The American', 2),
#              ('Communist', 2),
#              ('Irans', 2),
#              ('Hire American', 2),
#              ('Applause]If', 2),
#              ('Do Nothing Democrats', 1),
#              ('it?The Chinese', 1),
#              ('Afghanistanian', 1),
#              ('Schiff', 1),
#              ('nothingI', 1),
#              ('D.', 1),
#              ('Liberals', 1),
#              ('Turkish-American', 1),
#              ('Jewish-American', 1),
#              ('Towers', 1),
#              ('Nats', 1),
#              ('office?These', 1),
#              ('Libertarian', 1),
#              ('Boris', 1),
#              ('20 African American Democrats', 1),
#              ('Politicians', 1),
#              ('this?Nobody', 1),
#              ('Tulsi', 1),
#              ('Texan', 1),
#              ('Emmanuel', 1),
#              ('Italian-American', 1),
#              ('-American', 1),
#              ('Sicilian', 1),
#              ('Italian-Americans', 1),
#              ('Blues', 1),
#              ('Iraqis', 1),
#              ('I. D.', 1),
#              ('pro-Israel', 1),
#              ('business?So', 1),
#              ('Kody', 1),
#              ('Polish Americans', 1),
#              ('Floridian', 1),
#              ('Latinas', 1),
#              ('MollyTake', 1),
#              ('Narcotics', 1),
#              ('Dorian', 1),
#              ('Mountaineer', 1),
#              ('Clippers', 1),
#              ('Hurricane Dorian', 1),
#              ('Katherine', 1),
#              ('socialists', 1),
#              ('you?Our', 1),
#              ('Appalachian', 1),
#              ('Virginian', 1),
#              ('Roanoke', 1),
#              ('Virginians', 1),
#              ('Inaudible].These', 1),
#              ('Salute', 1),
#              ('Punishing Americans', 1),
#              ('Western', 1),
#              ('Continental Marines', 1),
#              ('Banner', 1),
#              ('Abram', 1),
#              ('something?Right', 1),
#              ('anti-Iraqi', 1),
#              ('Sarah?These', 1),
#              ('people?120,000', 1),
#              ('Headlines', 1),
#              ('Georgette', 1),
#              ('Germans', 1),
#              ('Alma', 1),
#              ('Falcons', 1),
#              ('Pegasus', 1),
#              ('anti-America', 1),
#              ('Beast', 1),
#              ('Florida Republican', 1),
#              ('Ash', 1),
#              ('right?Watch', 1),
#              ('100th', 1),
#              ('Latin', 1),
#              ('USMCA American', 1),
#              ('Colombian', 1),
#              ('Assange', 1),
#              ('non-Israeli', 1),
#              ('Socialists', 1),
#              ('Travis', 1),
#              ("right?They're", 1),
#              ('Caribbean', 1),
#              ('here?These', 1),
#              ('Specialist', 1),
#              ('Stryker', 1),
#              ('South American', 1),
#              ('Christ', 1),
#              ('Bostonian', 1),
#              ('Irishmen', 1),
#              ('Catholic Irish', 1),
#              ('Ethiopian', 1),
#              ('National Guardsman', 1),
#              ('Shepherds', 1),
#              ('Nino', 1),
#              ('All Americans', 1),
#              ('Anti-Semitic', 1),
#              ('Anglican', 1),
#              ('BuzzFeed', 1),
#              ('Central American', 1),
#              ('Congressional Democrats', 1),
#              ('Saints', 1),
#              ('french', 1),
#              ('please?These', 1),
#              ('sign?No', 1),
#              ('sign?So', 1),
#              ('Yazidis', 1),
#              ('Jewish-Americans', 1),
#              ('children?Anybody', 1),
#              ('Mississippi Republican', 1),
#              ('A1?Okay', 1),
#              ('FEMA.The', 1),
#              ('Suresnes American', 1),
#              ('from?Lebanon', 1),
#              ('Alaskans', 1),
#              ('Make American', 1),
#              ('border?These', 1),
#              ('The African Americans', 1),
#              ('the Hispanic Americans', 1),
#              ('Toro', 1),
#              ('Superman', 1),
#              ('Party', 1),
#              ('Applause]Hispanic American', 1),
#              ('Nationalist', 1),
#              ('a Hispanic American', 1),
#              ('North Vietnamese', 1),
#              ('Hatch', 1),
#              ('--The American', 1),
#              ('aliensAnd Republicans', 1),
#              ('Fakers', 1),
#              ('Tarkanian', 1),
#              ('Central European', 1),
#              ('Portman', 1),
#              ('that?African-Americans', 1),
#              ('Takur', 1),
#              ('Carpenters', 1),
#              ('that?Despite', 1),
#              ('Conservative', 1),
#              ('OK?African-American', 1),
#              ('Right?These', 1),
#              ('- African', 1),
#              ('Cyberspace Marines', 1),
#              ('Foxconn', 1),
#              ('Cristian', 1),
#              ('Booing]The Democrats', 1),
#              ('Angel', 1),
#              ('Great Americans', 1),
#              ('understanI', 1),
#              ('imagine?These', 1),
#              ('Alexes', 1),
#              ('Sentinel', 1),
#              ('ovarian', 1),
#              ('do-Democrats', 1),
#              ('Sentae Democrats', 1),
#              ('Southwest', 1),
#              ('Paralympians', 1),
#              ('Frenchmen', 1),
#              ('Free French', 1),
#              ('Frenchman', 1),
#              ('Sanders', 1),
#              ('Greek-American', 1),
#              ('a Conservative Democrat', 1),
#              ('Laughter].These', 1),
#              ('the South Korean', 1),
#              ('Neanderthal', 1),
#              ('somethingThe', 1),
#              ('Swedish', 1),
#              ('Charlotte', 1),
#              ('ex-marines', 1),
#              ('Curtis Hill', 1),
#              ('utopian', 1),
#              ('Applause]"Our', 1),
#              ('borderThese', 1),
#              ('independents', 1),
#              ('socialist', 1),
#              ('Pennsylvanians', 1),
#              ('discussion?Brooke', 1),
#              ('Anchor', 1),
#              ('Peggy', 1),
#              ('Hawaiian', 1),
#              ('My Fellow Americans', 1),
#              ('bottle]Japanese', 1),
#              ('Indonesians', 1),
#              ('Communism', 1),
#              ('Singaporean', 1),
#              ('the North Vietnamese', 1),
#              ('doubt?These', 1),
#              ('Evangelical-Christian', 1),
#              ('Sixty Hispanic Americans', 1),
#              ('Puerto Ricans', 1),
#              ('strength?Thank', 1),
#              ('Sasol', 1),
#              ('Yemeni', 1),
#              ('Brits', 1),
#              ('Bismarck', 1),
#              ('Southern Baptists', 1),
#              ('Niinistö', 1),
#              ('Finns', 1),
#              ('otherOur', 1),
#              ('ItÍs', 1),
#              ('Scotch', 1),
#              ('imagine?30', 1),
#              ('Croatian', 1),
#              ('Kushmans', 1),
#              ('Cuban Americans', 1),
#              ('Romanians', 1),
#              ('Jenean', 1),
#              ('all-Muslim', 1),
#              ('Great American', 1),
#              ('Coptic Christians', 1),
#              ('Fascism', 1),
#              ('Sunni', 1),
#              ('Sunnis', 1),
#              ('Midwestern', 1),
#              ('Aya', 1),
#              ('geese', 1),
#              ('Julian', 1),
#              ('Hindu', 1),
#              ('Painters', 1),
#              ('Politico', 1),
#              ('NASA.Human', 1),
#              ('Orient', 1),
#              ('Laughter]These', 1),
#              ('Selma', 1),
#              ('right?Pretty', 1),
#              ('story?Crazy', 1),
#              ('Greensboro', 1),
#              ('machinists', 1),
#              ('the Cuban Americans', 1),
#              ('in?All', 1)])

# %%
#displacy.render(nlp(str(r)), jupyter=True, style='ent')

# %%
#displacy.render(nlp(str(r)), style='dep', jupyter = True, options = {'distance': 120})

# %%
plt.figure(figsize=(20, 12))

y_pos = np.arange(len(person_counts.keys()))

plt.barh(y_pos, person_counts.values(), align='center', alpha=0.5)
plt.yticks(y_pos, person_counts.keys())

plt.show()

# %%
from pymarkovchain import MarkovChain
mc = MarkovChain()
for i in range(1,30):
    mc.generateDatabase(r)
    g = mc.generateString()
    print(g)
# Out:
# /home/luci/anaconda3/lib/python3.7/site-packages/pymarkovchain/MarkovChain.py:54: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn('Database file corrupt or not found, using empty database')
# WARNING:root:Database file corrupt or not found, using empty database
# You sought to gain easy entry into the conference
# We need steel
# They were going to bring up the Venezuelan people every one of the leaders, other than Manchin
# America's earliest Jewish communities, and good-paying jobs by cracking down strongly on having done an incredible relationship
# That's all right, you saw where they are not going to make you the most part, all they want our companies
# The one thing they did a job
# Can you believe, and keep all the wrong way, and I tell you what, we have to run anybody against him
# Thank you very much, by the sword, to a deduction for geese flying over the country together to negotiate and they've gone down in the United States
# So they're not going to happen, okay
# But we want it too
# [Applause] That's sounds -- maybe the greatest nation on your side, and I say to motivate and implement U
# The tunnel had caved in on a major disaster to the USA and China, as you just don't want to do it
# It will help give our great vets and you know, but we're going to New York skyline to the banks can go much higher than that, but I did a lot different
# After decades of economic development, workforce training, as part of it, you know, I'm in no rush
# And I -- I think the relationship is good climate as opposed to made a big percentage of it
# I want to suffocate our economy cannot take off the sidelines and back and operating immediately
# And people are so overproducing, and what I’m just saying, I don't have to have to get our steel companies are opening up a person you have -- and I see progress being made
# Is that true
# But the rest of the Western hemisphere who live under brutal oppression
# And they're being -- for North Korean representatives are dealing with them
# Our remains are coming from a Hillary Clinton deal
# Do we agree
# We have to have it with a great deal of tax reform, they are starting to go back to where you can divide that runs the business tax rate anywhere in the room also trace their roots to the Senate, we've confirmed an incredible welcoming ceremony earlier this year -- that's why we have tremendous stability
# That hasn't happened
# In every moment of it
# But hopefully it will restore the rule of law, and advance they did
# And by the way paid for it but the disease and the equal application of the shutdown, why do you have to shoot down rockets
# So fellas, we're holding you in
# [Laughter]

# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.generate()
# Out:
# [TOMT] [ASR] So has someone guys!!!!!!!! The most date on the same time in the snow day WWII

# %%
textgen.train_from_file('trump.txt', num_epochs=1)
textgen.generate()
# Out:
# 0 texts collected.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-0e9bffdea0b8> in <module>
# ----> 1 textgen.train_from_file('trump.txt', num_epochs=1)
#       2 textgen.generate()
#
# ~/anaconda3/lib/python3.7/site-packages/textgenrnn/textgenrnn.py in train_from_file(self, file_path, header, delim, new_model, context, is_csv, **kwargs)
#     327                 texts, context_labels=context_labels, **kwargs)
#     328         else:
# --> 329             self.train_on_texts(texts, context_labels=context_labels, **kwargs)
#     330
#     331     def train_from_largetext_file(self, file_path, new_model=True, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/textgenrnn/textgenrnn.py in train_on_texts(self, texts, context_labels, batch_size, num_epochs, verbose, new_model, gen_epochs, train_size, max_gen_length, validation, dropout, via_new_model, save_epochs, multi_gpu, **kwargs)
#     141         indices_list = [np.meshgrid(np.array(i), np.arange(
#     142             len(text) + 1)) for i, text in enumerate(texts)]
# --> 143         indices_list = np.block(indices_list)
#     144
#     145         # If a single text, there will be 2 extra indices, so remove them
#
# <__array_function__ internals> in block(*args, **kwargs)
#
# ~/.local/lib/python3.7/site-packages/numpy/core/shape_base.py in block(arrays)
#     833
#     834     """
# --> 835     arrays, list_ndim, result_ndim, final_size = _block_setup(arrays)
#     836
#     837     # It was found through benchmarking that making an array of final size
#
# ~/.local/lib/python3.7/site-packages/numpy/core/shape_base.py in _block_setup(arrays)
#     869         raise ValueError(
#     870             'List at {} cannot be empty'.format(
# --> 871                 _block_format_index(bottom_index)
#     872             )
#     873         )
#
# ValueError: List at arrays cannot be empty
